# %% [markdown]
# # Model Evaluation Notebook
#
# This notebook documents the evaluation workflow for the skin tone classifier, including accuracy, confusion matrix, and qualitative checks.

# %%
import json
from pathlib import Path

artifacts = Path('artifacts')
metrics_path = artifacts / 'evaluation.json'
if metrics_path.exists():
    print(json.loads(metrics_path.read_text())['accuracy'])
else:
    print('Run ml/training/evaluate.py after inference validation.')
